# %%
#read in graph
with open('SCC.txt') as f:
    data = f.readlines()

print("Number of Edges: {}".format(len(data)))
num_nodes = 875714

adj_list = {}
for x in range (1, num_nodes + 1):
    adj_list[x] = []
    
for line in data:
    src, dest = line.strip(' \n').split(' ')
    adj_list[int(src)].append(int(dest))
# Out:
# Number of Edges: 5105043

# %%
#create reverse graph
def rev_graph(adj_list):
    n_adj_list = {}
    for k in list(adj_list.keys()):
        n_adj_list[k] = []
        
    for k in list(adj_list.keys()):
        for l in adj_list[k]:
            n_adj_list[l].append(k)
            
    return n_adj_list
            
rev_adj_list = rev_graph(adj_list)

# %%
#dfs
def dfs(adj_list, vertex):
    stk = [vertex]
    visitedNodesList = []
    curr = 1
    while stk != [] :
        v = stk.pop()
        if v not in visitedNodes:
            stk += adj_list[v]
            visitedNodes.add(v)
            visitedNodesList.append(v)
    return visitedNodesList

# %%
visitedNodes = set()
curr = num_nodes
f = [0 for _ in range(num_nodes + 1)]
for i in range(1, num_nodes+1):
    if f[i] == 0:
        nodes = dfs(rev_adj_list, i)
        for n in nodes[::-1]:
            f[n] = curr
            curr -= 1

# %%
rev_order = [0 for _ in range(num_nodes+1)]
for i in range(num_nodes+1):
    rev_order[f[i]] = i

# %%
visitedNodes = set()
sccs = []
for i in range(1, num_nodes+1):
    if rev_order[i] not in visitedNodes:
        scc = dfs(adj_list, order[i])
        sccs.append(scc)

# %%
y = [len(x) for x in sccs]

# %%
sorted(y)[::-1]
# Out:
# [434821,
#  968,
#  459,
#  313,
#  211,
#  205,
#  197,
#  177,
#  173,
#  168,
#  162,
#  152,
#  149,
#  148,
#  138,
#  125,
#  122,
#  117,
#  117,
#  116,
#  106,
#  103,
#  102,
#  101,
#  99,
#  98,
#  98,
#  97,
#  96,
#  94,
#  94,
#  90,
#  89,
#  85,
#  85,
#  82,
#  81,
#  81,
#  81,
#  79,
#  78,
#  78,
#  78,
#  77,
#  75,
#  74,
#  74,
#  73,
#  72,
#  72,
#  72,
#  71,
#  71,
#  70,
#  70,
#  69,
#  69,
#  68,
#  68,
#  68,
#  67,
#  67,
#  65,
#  65,
#  65,
#  64,
#  64,
#  64,
#  63,
#  63,
#  60,
#  60,
#  59,
#  59,
#  58,
#  58,
#  58,
#  58,
#  58,
#  57,
#  56,
#  56,
#  56,
#  56,
#  56,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  54,
#  54,
#  54,
#  53,
#  53,
#  53,
#  52,
#  52,
#  52,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  49,
#  49,
#  49,
#  48,
#  48,
#  48,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  46,
#  46,
#  46,
#  46,
#  45,
#  45,
#  45,
#  45,
#  45,
#  45,
#  45,
#  45,
#  44,
#  44,
#  44,
#  44,
#  43,
#  43,
#  43,
# ...

# %%
import unittest

class Test(unittest.TestCase):

    def test_price_goes_up_then_down(self):
        x=3
        self.assertEqual(3,3)


unittest.main(verbosity=2)
# Out:
# C:\Users\osman\AppData\Roaming\jupyter\runtime\kernel-1b6e5b38-ac19-46e7-bc31-8d3dec4e3b7f (unittest.loader._FailedTest) ... ERROR
#
# ...
# ERROR: C:\Users\osman\AppData\Roaming\jupyter\runtime\kernel-1b6e5b38-ac19-46e7-bc31-8d3dec4e3b7f (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\osman\AppData\Roaming\jupyter\runtime\kernel-1b6e5b38-ac19-46e7-bc31-8d3dec4e3b7f'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.025s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# C:\Users\osman\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
